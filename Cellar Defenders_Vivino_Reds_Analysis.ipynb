# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('vivino_red_wine_072121.csv')

# %%
df.head()
# Out:
#                                           winery wine_type               city  \
# 0                       Ch?eau Mouton Rothschild  Red wine           Pauillac
# 1                              Dujac Fils et P?e  Red wine  Gevrey-Chambertin
# 2  Ch?eau Pichon Longueville Comtesse de Lalande  Red wine           Pauillac
# 3  Ch?eau Pichon Longueville Comtesse de Lalande  Red wine           Pauillac
# 4  Ch?eau Pichon Longueville Comtesse de Lalande  Red wine           Pauillac
#
#   country                            wine_name  year  overall_rating  \
# 0  France  Pauillac (Premier Grand Cru Class?)  1967             4.4
# 1  France                    Gevrey-Chambertin  2013             3.8
# 2  France          Pauillac (Grand Cru Class?)  1985             4.5
# 3  France          Pauillac (Grand Cru Class?)  1986             4.5
# 4  France          Pauillac (Grand Cru Class?)  1967             4.4
#
#    overall_rating_count    price  light_bold  smooth_tannic  dry_sweet  \
# ...

# %%
df.sort_values(by=['overall_rating','price'], ascending = False)
# Out:
#                 winery wine_type             city        country  \
# 16               Abreu  Red wine      Napa Valley  United States
# 110               Bond  Red wine      Napa Valley  United States
# 170       Sine Qua Non  Red wine  Sta. Rita Hills  United States
# 208      Peter Michael  Red wine     Sonoma Coast  United States
# 679              Realm  Red wine      Napa Valley  United States
# ...                ...       ...              ...            ...
# 43660  Mother's Choice  Red wine       California  United States
# 44158        Our Daily  Red wine       California  United States
# 27734    Pierre Chavin  Red wine        Languedoc         France
# 44159            Ariel  Red wine      Napa Valley  United States
# 44932              NaN       NaN              NaN            NaN
#
#                                               wine_name  year  overall_rating  \
# 16                        Thorevilos Cabernet Sauvignon  2006             4.9
# ...

# %%
df.shape
# Out:
# (44933, 13)

# %%
df.dtypes
# Out:
# winery                   object
# wine_type                object
# city                     object
# country                  object
# wine_name                object
# year                      int64
# overall_rating          float64
# overall_rating_count      int64
# price                   float64
# light_bold              float64
# smooth_tannic           float64
# dry_sweet               float64
# soft_acidic             float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44933 entries, 0 to 44932
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   winery                44932 non-null  object
#  1   wine_type             44932 non-null  object
#  2   city                  44928 non-null  object
#  3   country               44928 non-null  object
#  4   wine_name             44927 non-null  object
#  5   year                  44933 non-null  int64
#  6   overall_rating        44933 non-null  float64
#  7   overall_rating_count  44933 non-null  int64
#  8   price                 44933 non-null  float64
#  9   light_bold            44933 non-null  float64
#  10  smooth_tannic         44933 non-null  float64
#  11  dry_sweet             44933 non-null  float64
#  12  soft_acidic           44933 non-null  float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 4.5+ MB

# %%
print(df.describe())
# Out:
#                year  overall_rating  overall_rating_count         price  \
# count  44933.000000    44933.000000          44933.000000  44933.000000
# mean    2009.791445        3.998122            426.470345     75.365922
# std       86.163109        0.338457           1242.434541    108.794727
# min       -1.000000       -1.000000             -1.000000     -1.000000
# 25%     2012.000000        3.800000             56.000000     18.990000
# 50%     2015.000000        4.000000            129.000000     40.000000
# 75%     2017.000000        4.200000            361.000000     82.990000
# max     2020.000000        4.900000         134439.000000   4499.970000
#
#          light_bold  smooth_tannic    dry_sweet   soft_acidic
# count  44933.000000   44933.000000  44933.00000  44933.000000
# mean      57.657922      41.819262      7.07189     48.690204
# std       22.172399      19.220620      7.65284     19.457715
# min       -1.000000      -1.000000     -1.00000     -1.000000
# ...

# %%
df.city.value_counts()
# Out:
# city
# Napa Valley                                  3071
# California                                   1670
# Barolo                                       1313
# Toscana                                      1005
# Mendoza                                       963
#                                              ...
# Elkton Oregon                                   1
# Simonsberg-Stellenbosch                         1
# Morey-Saint-Denis 1er Cru 'Les Charri?es'       1
# Coal River Valley                               1
# Lison-Pramaggiore                               1
# Name: count, Length: 1180, dtype: int64

# %%
df.city.value_counts().hist(bins = 10)
# Out:
# <Axes: >
